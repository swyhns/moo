# %%
# 安装 Pyomo 和 HiGHS
# !pip install -q pyomo
# !apt-get install -y -qq coinor-libipopt-dev
# !pip install -q highspy

# %%
import pyomo.environ as pyo
from pyomo.opt import SolverFactory

# %% [markdown]
# 最小噪音

# %%
# 数据
_economy = [8, 10, 3, 5]
_heat = [0.3, 0.6, 0.1, 0.5]
_noise = [50, 120, 30, 80]

N = 4
I = range(N)

# 模型
model = pyo.ConcreteModel()
model.x = pyo.Var(I, domain=pyo.NonNegativeIntegers)
model.con = pyo.ConstraintList()
model.con.add(500 <= sum(_economy[i] * model.x[i] for i in I))
model.obj = pyo.Objective(expr=sum(_noise[i] * model.x[i] for i in I), sense=pyo.minimize)

# 使用 HiGHS 求解
solver = SolverFactory('highs')

solver.solve(model, tee=True)

# 输出结果
print(30*'-')
model.pprint()
print(30*'-')
model.display()
print(30*'-')
print(f"最优解: {pyo.value(model.obj)}")
print(30*'-')
print('各变量取值：')
for i in I:
    print(f'x[{i}] = {pyo.value(model.x[i])}')
print(30*'-')
# Out:
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 1 rows; 4 cols; 4 nonzeros; 4 integer variables (0 binary)
# Coefficient ranges:
#   Matrix [3e+00, 1e+01]
#   Cost   [3e+01, 1e+02]
#   Bound  [0e+00, 0e+00]
#   RHS    [5e+02, 5e+02]
# Presolving model
# 1 rows, 4 cols, 4 nonzeros  0s
# 1 rows, 4 cols, 4 nonzeros  0s
# Objective function is integral with scale 0.1
#
# Solving MIP model with:
#    1 rows
#    4 cols (0 binary, 4 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    4 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            6000               Large        0      0      0         0     0.0s
#  S       0       0         0   0.00%   0               3150             100.00%        0      0      0         0     0.0s
#          1       0         1 100.00%   3150            3150               0.00%        0      0      0         1     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      3150
#   Dual bound        3150
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.000529839878991
#   Solution status   feasible
#                     3150 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.01 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# ------------------------------
# 1 Var Declarations
#     x : Size=4, Index={0, 1, 2, 3}
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  63.0 :  None : False : False : NonNegativeIntegers
#           1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#
# 1 Objective Declarations
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 50*x[0] + 120*x[1] + 30*x[2] + 80*x[3]
#
# 1 Constraint Declarations
#     con : Size=1, Index={1}, Active=True
#         Key : Lower : Body                               : Upper : Active
#           1 : 500.0 : 8*x[0] + 10*x[1] + 3*x[2] + 5*x[3] :  +Inf :   True
#
# 3 Declarations: x con obj
# ------------------------------
# Model unknown
#
#   Variables:
#     x : Size=4, Index={0, 1, 2, 3}
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  63.0 :  None : False : False : NonNegativeIntegers
#           1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           2 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#
#   Objectives:
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Value
#         None :   True : 3150.0
#
#   Constraints:
#     con : Size=1
#         Key : Lower : Body  : Upper
#           1 : 500.0 : 504.0 :  None
# ------------------------------
# 最优解: 3150.0
# ------------------------------
# 各变量取值：
# x[0] = 63.0
# x[1] = 0.0
# x[2] = 0.0
# x[3] = 0.0
# ------------------------------

# %% [markdown]
# 最小热暴露

# %%
# 数据
_economy = [8, 10, 3, 5]
_heat = [0.3, 0.6, 0.1, 0.5]
_noise = [50, 120, 30, 80]

N = 4
I = range(N)

# 模型
model = pyo.ConcreteModel()
model.x = pyo.Var(I, domain=pyo.NonNegativeIntegers)
model.con = pyo.ConstraintList()
model.con.add(500 <= sum(_economy[i] * model.x[i] for i in I))
model.obj = pyo.Objective(expr=sum(_heat[i] * model.x[i] for i in I), sense=pyo.minimize)

# 使用 HiGHS 求解
solver = SolverFactory('highs')

solver.solve(model, tee=True)

# 输出结果
print(30*'-')
model.pprint()
print(30*'-')
model.display()
print(30*'-')
print(f"最优解: {pyo.value(model.obj)}")
print(30*'-')
print('各变量取值：')
for i in I:
    print(f'x[{i}] = {pyo.value(model.x[i])}')
print(30*'-')
# Out:
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 1 rows; 4 cols; 4 nonzeros; 4 integer variables (0 binary)
# Coefficient ranges:
#   Matrix [3e+00, 1e+01]
#   Cost   [1e-01, 6e-01]
#   Bound  [0e+00, 0e+00]
#   RHS    [5e+02, 5e+02]
# Presolving model
# 1 rows, 4 cols, 4 nonzeros  0s
# 1 rows, 4 cols, 4 nonzeros  0s
# Objective function is integral with scale 10
#
# Solving MIP model with:
#    1 rows
#    4 cols (0 binary, 4 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    4 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            30                 Large        0      0      0         0     0.0s
#  S       0       0         0   0.00%   0               16.7             100.00%        0      0      0         0     0.0s
#          1       0         1 100.00%   16.66666667     16.7               0.20%        0      0      0         1     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      16.7
#   Dual bound        16.7
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.000400350003423
#   Solution status   feasible
#                     16.7 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.01 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# ------------------------------
# 1 Var Declarations
#     x : Size=4, Index={0, 1, 2, 3}
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           2 :     0 : 167.0 :  None : False : False : NonNegativeIntegers
#           3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#
# 1 Objective Declarations
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 0.3*x[0] + 0.6*x[1] + 0.1*x[2] + 0.5*x[3]
#
# 1 Constraint Declarations
#     con : Size=1, Index={1}, Active=True
#         Key : Lower : Body                               : Upper : Active
#           1 : 500.0 : 8*x[0] + 10*x[1] + 3*x[2] + 5*x[3] :  +Inf :   True
#
# 3 Declarations: x con obj
# ------------------------------
# Model unknown
#
#   Variables:
#     x : Size=4, Index={0, 1, 2, 3}
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           2 :     0 : 167.0 :  None : False : False : NonNegativeIntegers
#           3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#
#   Objectives:
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Value
#         None :   True :  16.7
#
#   Constraints:
#     con : Size=1
#         Key : Lower : Body  : Upper
#           1 : 500.0 : 501.0 :  None
# ------------------------------
# 最优解: 16.7
# ------------------------------
# 各变量取值：
# x[0] = 0.0
# x[1] = 0.0
# x[2] = 167.0
# x[3] = 0.0
# ------------------------------

# %% [markdown]
# weighted sum method

# %%
# 数据
_economy = [8, 10, 3, 5]
_heat = [0.3, 0.6, 0.1, 0.5]
_noise = [50, 120, 30, 80]

w1=0.995
w2=1-w1

N = 4
I = range(N)

# 模型
model = pyo.ConcreteModel()
model.x = pyo.Var(I, domain=pyo.NonNegativeIntegers)
model.con = pyo.ConstraintList()
model.con.add(500 <= sum(_economy[i] * model.x[i] for i in I))
model.obj = pyo.Objective(expr=w1*sum(_heat[i] * model.x[i] for i in I)+w2*sum(_noise[i] * model.x[i] for i in I), sense=pyo.minimize)

# 使用 HiGHS 求解
solver = SolverFactory('highs')

solver.solve(model, tee=True)

# 输出结果
print(30*'-')
model.pprint()
print(30*'-')
model.display()
print(30*'-')
print(f"最优解: {pyo.value(model.obj)}")
print(30*'-')
print('各变量取值：')
for i in I:
    print(f'x[{i}] = {pyo.value(model.x[i])}')
print(30*'-')
# Out:
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 1 rows; 4 cols; 4 nonzeros; 4 integer variables (0 binary)
# Coefficient ranges:
#   Matrix [3e+00, 1e+01]
#   Cost   [2e-01, 1e+00]
#   Bound  [0e+00, 0e+00]
#   RHS    [5e+02, 5e+02]
# Presolving model
# 1 rows, 4 cols, 4 nonzeros  0s
# 1 rows, 4 cols, 4 nonzeros  0s
# Objective function is integral with scale 2000
#
# Solving MIP model with:
#    1 rows
#    4 cols (0 binary, 4 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    4 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            59.85              Large        0      0      0         0     0.0s
#  S       0       0         0   0.00%   0               34.5555          100.00%        0      0      0         0     0.0s
#  S       0       0         0   0.00%   34.28125        34.506             0.65%        0      0      0         1     0.0s
#  T       0       0         0   0.00%   34.368875       34.4565            0.25%        0      0      1         1     0.0s
#          1       0         1 100.00%   34.4565         34.4565            0.00%        0      0      1         1     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      34.4565
#   Dual bound        34.4565
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.000413694747175
#   Solution status   feasible
#                     34.4565 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.01 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# ------------------------------
# 1 Var Declarations
#     x : Size=4, Index={0, 1, 2, 3}
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  61.0 :  None : False : False : NonNegativeIntegers
#           1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           2 :     0 :   4.0 :  None : False : False : NonNegativeIntegers
#           3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#
# 1 Objective Declarations
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 0.995*(0.3*x[0] + 0.6*x[1] + 0.1*x[2] + 0.5*x[3]) + 0.0050000000000000044*(50*x[0] + 120*x[1] + 30*x[2] + 80*x[3])
#
# 1 Constraint Declarations
#     con : Size=1, Index={1}, Active=True
#         Key : Lower : Body                               : Upper : Active
#           1 : 500.0 : 8*x[0] + 10*x[1] + 3*x[2] + 5*x[3] :  +Inf :   True
#
# 3 Declarations: x con obj
# ------------------------------
# Model unknown
#
#   Variables:
#     x : Size=4, Index={0, 1, 2, 3}
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  61.0 :  None : False : False : NonNegativeIntegers
#           1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           2 :     0 :   4.0 :  None : False : False : NonNegativeIntegers
#           3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#
#   Objectives:
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Value
#         None :   True : 34.45650000000001
#
#   Constraints:
#     con : Size=1
#         Key : Lower : Body  : Upper
#           1 : 500.0 : 500.0 :  None
# ------------------------------
# 最优解: 34.45650000000001
# ------------------------------
# 各变量取值：
# x[0] = 61.0
# x[1] = 0.0
# x[2] = 4.0
# x[3] = 0.0
# ------------------------------

# %% [markdown]
# compromise programming

# %%
# 数据
_economy = [8, 10, 3, 5]
_heat = [0.3, 0.6, 0.1, 0.5]
_noise = [50, 120, 30, 80]

w1=0.995
w2=1-w1

f1min=16.7
f2min=3150

N = 4
I = range(N)

# 模型
model = pyo.ConcreteModel()
model.x = pyo.Var(I, domain=pyo.NonNegativeIntegers)
model.con = pyo.ConstraintList()
model.con.add(500 <= sum(_economy[i] * model.x[i] for i in I))
model.obj = pyo.Objective(expr=w1*(sum(_heat[i] * model.x[i] for i in I)-f1min)+w2*(sum(_noise[i] * model.x[i] for i in I)-f1min), sense=pyo.minimize)

# 使用 HiGHS 求解
solver = SolverFactory('highs')

solver.solve(model, tee=True)

# 输出结果
print(30*'-')
model.pprint()
print(30*'-')
model.display()
print(30*'-')
print(f"最优解: {pyo.value(model.obj)}")
print(30*'-')
print('各变量取值：')
for i in I:
    print(f'x[{i}] = {pyo.value(model.x[i])}')
print(30*'-')
# Out:
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 1 rows; 4 cols; 4 nonzeros; 4 integer variables (0 binary)
# Coefficient ranges:
#   Matrix [3e+00, 1e+01]
#   Cost   [2e-01, 1e+00]
#   Bound  [0e+00, 0e+00]
#   RHS    [5e+02, 5e+02]
# Presolving model
# 1 rows, 4 cols, 4 nonzeros  0s
# 1 rows, 4 cols, 4 nonzeros  0s
# Objective function is integral with scale 2000
#
# Solving MIP model with:
#    1 rows
#    4 cols (0 binary, 4 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    4 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            43.15              Large        0      0      0         0     0.0s
#  S       0       0         0   0.00%   -16.7           17.8555          193.53%        0      0      0         0     0.0s
#  S       0       0         0   0.00%   17.58125        17.806             1.26%        0      0      0         1     0.0s
#  T       0       0         0   0.00%   17.668875       17.7565            0.49%        0      0      1         1     0.0s
#          1       0         1 100.00%   17.7565         17.7565            0.00%        0      0      1         1     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      17.7565
#   Dual bound        17.7565
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.000580419133756
#   Solution status   feasible
#                     17.7565 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.02 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# ------------------------------
# 1 Var Declarations
#     x : Size=4, Index={0, 1, 2, 3}
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  61.0 :  None : False : False : NonNegativeIntegers
#           1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           2 :     0 :   4.0 :  None : False : False : NonNegativeIntegers
#           3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#
# 1 Objective Declarations
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 0.995*(0.3*x[0] + 0.6*x[1] + 0.1*x[2] + 0.5*x[3] - 16.7) + 0.0050000000000000044*(50*x[0] + 120*x[1] + 30*x[2] + 80*x[3] - 16.7)
#
# 1 Constraint Declarations
#     con : Size=1, Index={1}, Active=True
#         Key : Lower : Body                               : Upper : Active
#           1 : 500.0 : 8*x[0] + 10*x[1] + 3*x[2] + 5*x[3] :  +Inf :   True
#
# 3 Declarations: x con obj
# ------------------------------
# Model unknown
#
#   Variables:
#     x : Size=4, Index={0, 1, 2, 3}
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  61.0 :  None : False : False : NonNegativeIntegers
#           1 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#           2 :     0 :   4.0 :  None : False : False : NonNegativeIntegers
#           3 :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#
#   Objectives:
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Value
#         None :   True : 17.756500000000013
#
#   Constraints:
#     con : Size=1
#         Key : Lower : Body  : Upper
#           1 : 500.0 : 500.0 :  None
# ------------------------------
# 最优解: 17.756500000000013
# ------------------------------
# 各变量取值：
# x[0] = 61.0
# x[1] = 0.0
# x[2] = 4.0
# x[3] = 0.0
# ------------------------------

# %% [markdown]
# ε-constraint

# %%
# 数据
_economy = [8, 10, 3, 5]
_heat = [0.3, 0.6, 0.1, 0.5]
_noise = [50, 120, 30, 80]

N = 4
I = range(N)
f1min=16.7
f2min=3150
_epsilon = 0.1

# 模型
model = pyo.ConcreteModel()
model.x = pyo.Var(I, domain=pyo.NonNegativeIntegers)
model.con = pyo.ConstraintList()
model.con.add(500 <= sum(_economy[i] * model.x[i] for i in I))
model.con.add( f1min * (1 + _epsilon ) >= sum( _heat[i]*model.x[i] for i in I) )
model.obj = pyo.Objective(expr=sum(_noise[i] * model.x[i] for i in I), sense=pyo.minimize)

# 使用 HiGHS 求解
solver = SolverFactory('highs')

solver.solve(model, tee=True)

# 输出结果
print(30*'-')
model.pprint()
print(30*'-')
model.display()
print(30*'-')
print(f"最优解: {pyo.value(model.obj)}")
print(30*'-')
print('各变量取值：')
for i in I:
    print(f'x[{i}] = {pyo.value(model.x[i])}')
print(30*'-')
# Out:
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 2 rows; 4 cols; 8 nonzeros; 4 integer variables (0 binary)
# Coefficient ranges:
#   Matrix [1e-01, 1e+01]
#   Cost   [3e+01, 1e+02]
#   Bound  [0e+00, 0e+00]
#   RHS    [2e+01, 5e+02]
# Presolving model
# 2 rows, 4 cols, 8 nonzeros  0s
# 2 rows, 3 cols, 6 nonzeros  0s
# Objective function is integral with scale 0.1
#
# Solving MIP model with:
#    2 rows
#    3 cols (0 binary, 3 integer, 0 implied int., 0 continuous, 0 domain fixed)
#    6 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            4950               Large        0      0      0         0     0.0s
#  T       0       0         0   0.00%   0               3530             100.00%        0      0      0         2     0.0s
#          1       0         1 100.00%   3530            3530               0.00%        0      0      0         2     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      3530
#   Dual bound        3530
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.000445365905762
#   Solution status   feasible
#                     3530 (objective)
#                     0 (bound viol.)
#                     2.13162820728e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.02 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# ------------------------------
# 1 Var Declarations
#     x : Size=4, Index={0, 1, 2, 3}
#         Key : Lower : Value             : Upper : Fixed : Stale : Domain
#           0 :     0 : 49.00000000000001 :  None : False : False : NonNegativeIntegers
#           1 :     0 :               0.0 :  None : False : False : NonNegativeIntegers
#           2 :     0 : 35.99999999999998 :  None : False : False : NonNegativeIntegers
#           3 :     0 :               0.0 :  None : False : False : NonNegativeIntegers
#
# 1 Objective Declarations
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 50*x[0] + 120*x[1] + 30*x[2] + 80*x[3]
#
# 1 Constraint Declarations
#     con : Size=2, Index={1, 2}, Active=True
#         Key : Lower : Body                                      : Upper : Active
#           1 : 500.0 :        8*x[0] + 10*x[1] + 3*x[2] + 5*x[3] :  +Inf :   True
#           2 :  -Inf : 0.3*x[0] + 0.6*x[1] + 0.1*x[2] + 0.5*x[3] : 18.37 :   True
#
# 3 Declarations: x con obj
# ------------------------------
# Model unknown
#
#   Variables:
#     x : Size=4, Index={0, 1, 2, 3}
#         Key : Lower : Value             : Upper : Fixed : Stale : Domain
#           0 :     0 : 49.00000000000001 :  None : False : False : NonNegativeIntegers
#           1 :     0 :               0.0 :  None : False : False : NonNegativeIntegers
#           2 :     0 : 35.99999999999998 :  None : False : False : NonNegativeIntegers
#           3 :     0 :               0.0 :  None : False : False : NonNegativeIntegers
#
#   Objectives:
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Value
#         None :   True : 3530.0
#
#   Constraints:
#     con : Size=2
#         Key : Lower : Body               : Upper
#           1 : 500.0 :              500.0 :  None
#           2 :  None : 18.299999999999997 : 18.37
# ------------------------------
# 最优解: 3530.0
# ------------------------------
# 各变量取值：
# x[0] = 49.00000000000001
# x[1] = 0.0
# x[2] = 35.99999999999998
# x[3] = 0.0
# ------------------------------

# %% [markdown]
# Min-max method

# %%
# 数据
_economy = [8, 10, 3, 5]
_heat = [0.3, 0.6, 0.1, 0.5]
_noise = [50, 120, 30, 80]

N = 4
I = range(N)
f1min=16.7
f2min=3150
_epsilon = 0.1

# 模型
model = pyo.ConcreteModel()

model.x = pyo.Var(I, domain = pyo.NonNegativeIntegers)

model.y = pyo.Var()


model.con = pyo.ConstraintList()

model.con.add(500 <= sum(_economy[i] * model.x[i] for i in I))

model.con.add( model.y >= -f1min + sum(  _heat[i]*model.x[i] for i in I) )
model.con.add( model.y >= -f2min + sum( _noise[i]*model.x[i] for i in I) )

model.obj = pyo.Objective(expr= model.y, sense = pyo.minimize)


# 使用 HiGHS 求解
solver = SolverFactory('highs')

solver.solve(model, tee=True)

# 输出结果
print(30*'-')
model.pprint()
print(30*'-')
model.display()
print(30*'-')
print(f"最优解: {pyo.value(model.obj)}")
print(30*'-')
print('各变量取值：')
for i in I:
    print(f'x[{i}] = {pyo.value(model.x[i])}')
print(30*'-')
# Out:
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 3 rows; 5 cols; 14 nonzeros; 4 integer variables (0 binary)
# Coefficient ranges:
#   Matrix [1e-01, 1e+02]
#   Cost   [1e+00, 1e+00]
#   Bound  [0e+00, 0e+00]
#   RHS    [2e+01, 3e+03]
# Presolving model
# 3 rows, 5 cols, 14 nonzeros  0s
# 3 rows, 4 cols, 11 nonzeros  0s
#
# Solving MIP model with:
#    3 rows
#    4 cols (0 binary, 3 integer, 0 implied int., 1 continuous, 0 domain fixed)
#    11 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -16.7           inf                  inf        0      0      0         0     0.0s
#  R       0       0         0   0.00%   2.019977802     10                79.80%        0      0      0         3     0.0s
#  T       0       0         0 100.00%   2.178217822     2.2                0.99%       11      4      0         8     0.0s
#          1       0         1 100.00%   2.2             2.2                0.00%       11      4      0         8     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      2.2
#   Dual bound        2.2
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.00511285124716
#   Solution status   feasible
#                     2.2 (objective)
#                     0 (bound viol.)
#                     6.44225413754e-13 (int. viol.)
#                     0 (row viol.)
#   Timing            0.03 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     8 (total)
#                     0 (strong br.)
#                     5 (separation)
#                     0 (heuristics)
# ------------------------------
# 2 Var Declarations
#     x : Size=4, Index={0, 1, 2, 3}
#         Key : Lower : Value                  : Upper : Fixed : Stale : Domain
#           0 :     0 :      63.00000000000035 :  None : False : False : NonNegativeIntegers
#           1 :     0 :                    0.0 :  None : False : False : NonNegativeIntegers
#           2 :     0 : -6.442254137536459e-13 :  None : False : False : NonNegativeIntegers
#           3 :     0 :                    0.0 :  None : False : False : NonNegativeIntegers
#     y : Size=1, Index=None
#         Key  : Lower : Value              : Upper : Fixed : Stale : Domain
#         None :  None : 2.2000000000000415 :  None : False : False :  Reals
#
# 1 Objective Declarations
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize :          y
#
# 1 Constraint Declarations
#     con : Size=3, Index={1, 2, 3}, Active=True
#         Key : Lower : Body                                                 : Upper : Active
#           1 : 500.0 :                   8*x[0] + 10*x[1] + 3*x[2] + 5*x[3] :  +Inf :   True
#           2 :  -Inf : 0.3*x[0] + 0.6*x[1] + 0.1*x[2] + 0.5*x[3] - 16.7 - y :   0.0 :   True
#           3 :  -Inf :    50*x[0] + 120*x[1] + 30*x[2] + 80*x[3] - 3150 - y :   0.0 :   True
#
# 4 Declarations: x y con obj
# ------------------------------
# Model unknown
#
#   Variables:
#     x : Size=4, Index={0, 1, 2, 3}
#         Key : Lower : Value                  : Upper : Fixed : Stale : Domain
#           0 :     0 :      63.00000000000035 :  None : False : False : NonNegativeIntegers
#           1 :     0 :                    0.0 :  None : False : False : NonNegativeIntegers
#           2 :     0 : -6.442254137536459e-13 :  None : False : False : NonNegativeIntegers
#           3 :     0 :                    0.0 :  None : False : False : NonNegativeIntegers
#     y : Size=1, Index=None
#         Key  : Lower : Value              : Upper : Fixed : Stale : Domain
#         None :  None : 2.2000000000000415 :  None : False : False :  Reals
#
#   Objectives:
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Value
#         None :   True : 2.2000000000000415
#
#   Constraints:
#     con : Size=3
#         Key : Lower : Body                  : Upper
#           1 : 500.0 :    504.00000000000085 :  None
#           2 :  None : 4.440892098500626e-16 :   0.0
#           3 :  None :   -2.2000000000018605 :   0.0
# ------------------------------
# 最优解: 2.2000000000000415
# ------------------------------
# 各变量取值：
# x[0] = 63.00000000000035
# x[1] = 0.0
# x[2] = -6.442254137536459e-13
# x[3] = 0.0
# ------------------------------
